# %%
import os , sys
sys.path.append(os.path.abspath('../scripts'))

# %%
import eda as eda

# %% [markdown]
# # Loading the Data

# %%
path = '../data/data.csv'
data = eda.load_data(path)
data.head()
# Out:
# 2024-10-06 12:21:11,334 - root - INFO - loading the data set into the pandas data frame
# 2024-10-06 12:21:11,336 - root - INFO - the data set loaded succesfully
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# ...

# %% [markdown]
# # Overview of The Data set

# %%
eda.overview_the_data(data)
# Out:
# 2024-10-06 12:21:11,925 - root - INFO - showing the overview of he data
# 2024-10-06 12:21:11,925 - root - INFO - the data set have 16 columns and 95662 rows
# 2024-10-06 12:21:11,931 - root - INFO - the data set columns data types
#  TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object

# %% [markdown]
# # General Summary Statistics

# %%
eda.summary_statistics(data)
# Out:
# 2024-10-06 12:21:11,946 - root - INFO - trying to perfomr the summary statistics
# 2024-10-06 12:21:11,996 - root - INFO - the statistical summaery is
#         CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %% [markdown]
# # Analysis for the Distribution for the numeric features

# %%
eda.distribution_of_numerical_features(data)
# Out:
# 2024-10-06 12:21:12,013 - root - INFO - perfomring the process to show the distribution of numerical features
# 2024-10-06 12:21:12,016 - root - INFO - selecting columns of the numeric columns only
# 2024-10-06 12:21:12,021 - root - INFO - visualing the numeric data
# 2024-10-06 12:21:13,590 - root - INFO - box plot for outliers for numeric columns
# Skewnwss for Numerical Features:
#  CountryCode         0.000000
# Amount             51.098490
# Value              51.291086
# PricingStrategy     1.659057
# FraudResult        22.196295
# dtype: float64

# %% [markdown]
# # Analysis for the Distribution for the catacorical features

# %%
eda.distribution_of_catagorical_features(data)
# Out:
# 2024-10-06 12:23:53,600 - root - INFO - perfomring the process to show the distribution of catagorical features
# Number of unique categories per categorical feature:
#  TransactionId           95662
# BatchId                 94809
# AccountId                3633
# SubscriptionId           3627
# CustomerId               3742
# CurrencyCode                1
# ProviderId                  6
# ProductId                  23
# ProductCategory             9
# ChannelId                   4
# TransactionStartTime    94556
# dtype: int64

# %% [markdown]
# # Correlation matrix for the Numerical features

# %%
eda.correlation_matrix_for_numerical_features(data)
# Out:
# 2024-10-06 14:43:03,248 - root - INFO - performing the correlation matrix for the numeric features
# None
# Highly correlated features:
#                   CountryCode    Amount     Value  PricingStrategy  FraudResult
# CountryCode              NaN       NaN       NaN              NaN          NaN
# Amount                   NaN  1.000000  0.989692              NaN          NaN
# Value                    NaN  0.989692  1.000000              NaN          NaN
# PricingStrategy          NaN       NaN       NaN              1.0          NaN
# FraudResult              NaN       NaN       NaN              NaN          1.0

# %% [markdown]
# # check for missing Values and if there is any take measure

# %%
eda.check_for_missing_values(data)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # Outliers Detection for the Numeric columns

# %%
eda.outlier_detection_for_numeric_cols(data)
# Out:
# 2024-10-06 14:46:01,118 - root - INFO - detecting outliers for numerical columns
